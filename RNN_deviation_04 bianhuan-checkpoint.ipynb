# %%
import torch
from torch import nn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Load data

# %%
# model_1 is egg 
# model_2 is PMD 
# model_3 is TDP 

filepath_model_1 = "data/egg_distance_stl_Cloud.csv"
filepath_model_2 = "data/PMD_distance_stl - Cloud.csv"
filepath_model_3 = "data/TDP_distance_stl - Cloud.csv"

model_1 = pd.read_csv(filepath_model_1)
model_2 = pd.read_csv(filepath_model_2)
model_3 = pd.read_csv(filepath_model_3)
model_1.head()
# Out:
#          //X          Y         Z  Temp. approx. distances  \
# 0  19.068060 -11.560005  0.000004                -0.306077
# 1  19.068062 -11.559999  0.000004                -0.306077
# 2 -19.069937  11.558008  0.000004                -0.425199
# 3 -19.069939  11.558002  0.000004                -0.425198
# 4  18.070063 -16.384005  0.000004                -0.186776
#
#    Roughness (0.781197)  Mean curvature (0.781197)  \
# 0              0.000816                   0.001143
# 1              0.000818                   0.001143
# 2              0.000053                   0.000255
# 3              0.000055                   0.000255
# 4              0.000818                   0.002835
#
#    Gaussian curvature (0.781197)  Normal change rate (0.781197)  \
# 0                       0.000000                       0.000001
# 1                       0.000000                       0.000001
# 2                       0.000028                       0.000001
# 3                       0.000028                       0.000001
# 4                       0.000002                       0.000001
#
#    Number of neighbors (r=0.781197)  Surface density (r=0.781197)  ...  \
# 0                              13.0                      6.780665  ...
# 1                              13.0                      6.780665  ...
# 2                              13.0                      6.780665  ...
# 3                              13.0                      6.780665  ...
# 4                              13.0                      6.780665  ...
#
#    Planarity (0.781197)  Linearity (0.781197)  PCA1 (0.781197)  \
# 0              0.276412              0.723587         0.783444
# 1              0.276412              0.723587         0.783444
# 2              0.276381              0.723618         0.783463
# 3              0.276381              0.723618         0.783463
# 4              0.276605              0.723393         0.783326
#
#    PCA2 (0.781197)  Surface variation (0.781197)  Sphericity (0.781197)  \
# 0         0.216554                      0.000001               0.000002
# 1         0.216554                      0.000001               0.000002
# 2         0.216535                      0.000001               0.000002
# 3         0.216535                      0.000001               0.000002
# 4         0.216673                      0.000001               0.000002
#
#    Verticality (0.781197)        Nx        Ny        Nz
# 0                0.764433  0.951514 -0.196258  0.236863
# 1                0.764433  0.000978  0.000978  0.999999
# 2                0.762576 -0.950901  0.196132  0.239416
# 3                0.762576  0.000978  0.000978  0.999999
# 4                0.761185  0.950131 -0.199243  0.239905
#
# [5 rows x 25 columns]

# %%
layer_number_1 = model_1['Z'].value_counts().sort_index()
layer_number_2 = model_2['Z'].value_counts().sort_index()
layer_number_3 = model_3['Z'].value_counts().sort_index()

layer_number_1.plot()
layer_number_2.plot()
layer_number_3.plot()
plt.show()

# %% [markdown]
# ### Preprocessing

# %%
def Preprocessing(model_1):
    # add a column as approximate z where delta z = 0.1
    model_1['appro_z'] = round(model_1['Z']*2)/2
    layer_number_1 = model_1['appro_z'].value_counts().sort_index()
    
    # add a column ['theta'] as theta
    model_1['theta'] = model_1.apply(lambda x: np.arctan2(x['Y'],x['//X']), axis = 1)
    model_1['theta']
    
    # add a column ['R'] as the radius in polar coordinates
    R2 = model_1.apply(lambda x: x['//X']**2 + x['Y']**2 + x['Z']**2 ,axis = 1)
    model_1['R'] = np.sqrt(R2)
    model_1['R']
    
    # add a column ['r'] as the radius in cylindrical coordinates
    r2 = model_1.apply(lambda x: x['//X']**2 + x['Y']**2,axis = 1)
    model_1['r'] = np.sqrt(r2)
    model_1['r']
    return model_1.head()

# %%
Preprocessing(model_1)
Preprocessing(model_2)
Preprocessing(model_3)
# Out:
#          //X          Y         Z  Temp. approx. distances  \
# 0  16.506958 -11.407999  0.007309                -0.251701
# 1  16.263357 -11.827134  0.007309                -0.277180
# 2 -16.508957 -11.407999  0.007309                -0.069784
# 3 -16.523348 -11.383106  0.007309                -0.067225
# 4 -16.239000 -11.875999  0.007309                -0.029465
#
#    Roughness (0.854526)  Mean curvature (0.854526)  \
# 0              0.001076                   0.001419
# 1              0.000463                   0.001603
# 2              0.000391                   0.001048
# 3              0.000450                   0.000199
# 4              0.000628                   0.001394
#
#    Gaussian curvature (0.854526)  Normal change rate (0.854526)  \
# 0                       0.000041                       0.000002
# 1                       0.000003                       0.000001
# 2                       0.000003                       0.000001
# 3                       0.000008                       0.000001
# 4                       0.000003                       0.000001
#
#    Number of neighbors (r=0.854526)  Surface density (r=0.854526)  ...  \
# 0                              20.0                      8.718255  ...
# 1                              21.0                      9.154167  ...
# 2                              20.0                      8.718255  ...
# 3                              21.0                      9.154167  ...
# 4                              21.0                      9.154167  ...
#
#    Surface variation (0.854526)  Sphericity (0.854526)  \
# 0                      0.000002               0.000003
# 1                      0.000001               0.000001
# 2                      0.000001               0.000001
# 3                      0.000001               0.000001
# 4                      0.000001               0.000001
#
#    Verticality (0.854526)        Nx        Ny        Nz  appro_z     theta  \
# 0                0.887594  0.859991 -0.498192  0.110550      0.0 -0.604729
# 1                0.887160  0.859714 -0.498031  0.113385      0.0 -0.628766
# 2                0.886184 -0.860942 -0.495868  0.113547      0.0 -2.536920
# 3                0.886254 -0.860942 -0.495868  0.113547      0.0 -2.538348
# 4                0.885942 -0.859714 -0.498031  0.113385      0.0 -2.510151
#
#            R          r
# 0  20.065447  20.065446
# 1  20.109151  20.109149
# 2  20.067091  20.067090
# 3  20.064800  20.064798
# 4  20.118264  20.118263
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Build a batch
# batch shape: [theta, x, y, z ... other features]
#
# Here theta is the approximate theta. We divide a circle into 500 pieces, take the nearest point as the sample point.
#
# It should be noticed that when we take the sample points, we use approximate z as the criteria of one layer.But we keep the original z values as input.
#
# output shape: ['Temp. approx. distances'] shape(model_size,batch_size,1)

# %%
def build_batch(model_1):
    # precision
    model_size = len(model_1.groupby(['appro_z']).size()) # how many layers we have == batch size
    theta_size = 500 # how many pieces in one layer == time step
    feature_len = len(model_1.columns)  # how many features we have (‘appro z’ is not a feature)
    
    index = model_1.columns # store the column title 
    input_seq = np.zeros((model_size,theta_size,feature_len), dtype = np.float32)
    output_seq = np.zeros((model_size,theta_size,1), dtype = np.float32)

    for i in range (model_size):
        for u in range(theta_size):
            target_theta = (np.pi * 2 / 500 * u)-np.pi
            current_layer = 0.5 * i
            current = model_1[model_1['appro_z'] == current_layer]

            if len(current) != 0:
            # find the point that is nearest the target angle
                sample_ID = current['theta'].map(lambda x : abs(x-target_theta)).idxmin()
                current = current.loc[sample_ID]
                output_seq[i,u] = current['Temp. approx. distances']

                current = current.drop(labels = ['appro_z'])
                current = pd.concat([pd.Series([target_theta]), current], ignore_index = True)
                input_seq[i,u] = current
    return input_seq, output_seq

# %%
input1, output1 = build_batch(model_1)
input2, output2 = build_batch(model_2)
input3, output3 = build_batch(model_3)

# %% [markdown]
# (1)画出input1[:][:][0:3] 保证放到cloudcompare里是个完整模型
#
# (2)把input1 转换成n*feautrenumber

# %%
def features2dataframe(features):
    model_size = features.shape[0] # how many layers we have == batch size
    theta_size = features.shape[1] # how many pieces in one layer == time step
    feature_len = features.shape[2]  # how many features we have (‘appro z’ is not a feature)
    
    column = ['target_theta','//X', 'Y', 'Z', 'Temp. approx. distances', 'Roughness (0.781197)',
           'Mean curvature (0.781197)', 'Gaussian curvature (0.781197)',
           'Normal change rate (0.781197)', 'Number of neighbors (r=0.781197)',
           'Surface density (r=0.781197)', 'Volume density (r=0.781197)',
           'Eigenvalues sum (0.781197)', 'Omnivariance (0.781197)',
           'Eigenentropy (0.781197)', 'Anisotropy (0.781197)',
           'Planarity (0.781197)', 'Linearity (0.781197)', 'PCA1 (0.781197)',
           'PCA2 (0.781197)', 'Surface variation (0.781197)',
           'Sphericity (0.781197)', 'Verticality (0.781197)', 'Nx', 'Ny', 'Nz', 
            'real_theta', 'R', 'r']

    df = []
    for i in range(model_size):
        for u in range(theta_size):
            current = features[i][u]
            df.append(current)
    df = pd.DataFrame(df, columns = column)
    return df

# %%
predict_input = features2dataframe(input3)
predict_input[['//X', 'Y', 'Z']].to_numpy()
# input2 = features2dataframe(input2)
# input3 = features2dataframe(input3)
# input1.head()

# %%
# print(input1['target_theta'].min())
# print(input1['target_theta'].max())

# %%
print(input1[0][0:3][:])
print(output1[0][0:3][:])

# %%
input = np.concatenate((input1, input2), axis=0)
input = np.delete(input,0,2)
input = np.delete(input,3,2)
output = np.concatenate((output1, output2), axis=0)
output = output*10
print(np.shape(output))
print(np.shape(input))

# %%
print(input[0][0][:])
len(input[0][0][:])

# %%
# Hyper Parameters
#  model_size = len(model_1.groupby(['appro_z']).size()) # how many layers we have
#  theta_size = 500 # how many pieces in one layer
#  feature_len = len(model_1.columns)  # how many features we have (‘appro z’ is not a feature)
TIME_STEP = 500      # rnn time step
INPUT_SIZE = len(input[0][0][:])      # rnn input size
LR = 0.02           # learning rate

# %%
# # show data
# steps = np.linspace(0, np.pi*2, 100, dtype=np.float32)  # float32 for converting torch FloatTensor
# x_np = np.sin(steps)
# y_np = np.cos(steps)
# plt.plot(steps, y_np, 'r-', label='target (cos)')
# plt.plot(steps, x_np, 'b-', label='input (sin)')
# plt.legend(loc='best')
# plt.show()

# %%
# class RNN(nn.Module):
#     def __init__(self):
#         super(RNN, self).__init__()

#         self.rnn = nn.RNN(
#             input_size=INPUT_SIZE,
#             hidden_size=32,     # rnn hidden unit
#             num_layers=1,       # number of rnn layer
#             batch_first=True,   # input & output will has batch size as 1s dimension. e.g. (batch, time_step, input_size)
#         )
#         self.out = nn.Linear(32, 1)

#     def forward(self, x, h_state):
#         # x (batch, time_step, input_size)
#         # h_state (n_layers, batch, hidden_size)
#         # r_out (batch, time_step, hidden_size)
#         r_out, h_state = self.rnn(x, h_state)

#         outs = []    # save all predictions
#         for time_step in range(r_out.size(1)):    # calculate output for each time step
#             outs.append(self.out(r_out[:, time_step, :]))
#         return torch.stack(outs, dim=1), h_state
    
# rnn = RNN()
# print(rnn)

# %%
# optimizer = torch.optim.Adam(rnn.parameters(), lr=LR)   # optimize all cnn parameters
# loss_func = nn.MSELoss()

# h_state = None      # for initial hidden state

# # plt.figure(1, figsize=(12, 5))
# # plt.ion()           # continuously plot

# for step in range(500):
# #     start, end = step * np.pi, (step+1)*np.pi   # time range
# #     # use sin predicts cos
# #     steps = np.linspace(start, end, TIME_STEP, dtype=np.float32, endpoint=False)  # float32 for converting torch FloatTensor
# #     x_np = np.sin(steps)
# #     y_np = np.cos(steps)

# #     x = torch.from_numpy(x_np[np.newaxis, :, np.newaxis])    # shape (batch, time_step, input_size)
# #     y = torch.from_numpy(y_np[np.newaxis, :, np.newaxis])
#     input1_torch = torch.from_numpy(input1)
#     output1_torch = torch.from_numpy(output1)
# #     print(input1_torch.size())
#     prediction, h_state = rnn(input1_torch, h_state)   # rnn output
#     # !! next step is important !!
#     h_state = h_state.data        # repack the hidden state, break the connection from last iteration

#     loss = loss_func(prediction, output1_torch)         # calculate loss
#     print(loss)
#     optimizer.zero_grad()                   # clear gradients for this training step
#     loss.backward()                         # backpropagation, compute gradients
#     optimizer.step()                        # apply gradients
    
#     # plotting
# #     plt.plot(steps, y_np.flatten(), 'r-')
# #     plt.plot(steps, prediction.data.numpy().flatten(), 'b-')
#     if step % 10 == 0:
#         plt.plot(output1.flatten(), 'r-')
#         plt.plot(prediction.data.numpy().flatten(), 'b-')
#         plt.draw(); plt.pause(0.05)

# %%
class RNN(nn.Module):
    def __init__(self):
        super(RNN, self).__init__()

        self.rnn = nn.LSTM(         # if use nn.RNN(), it hardly learns
            input_size=INPUT_SIZE,
            hidden_size=64,         # rnn hidden unit
            num_layers=1,           # number of rnn layer
            batch_first=True,       # input & output will has batch size as 1s dimension. e.g. (batch, time_step, input_size)
        )

        self.out = nn.Linear(64, 1)

    def forward(self, x):
        # x shape (batch, time_step, input_size)
        # r_out shape (batch, time_step, output_size)
        # h_n shape (n_layers, batch, hidden_size)
        # h_c shape (n_layers, batch, hidden_size)
        r_out, (h_n, h_c) = self.rnn(x, None)   # None represents zero initial hidden state

        outs = []    # save all predictions
        for time_step in range(r_out.size(1)):    # calculate output for each time step
            outs.append(self.out(r_out[:, time_step, :]))
        return torch.stack(outs, dim=1)


rnn = RNN()
print(rnn)
# Out:
# RNN(
#   (rnn): LSTM(27, 64, batch_first=True)
#   (out): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
optimizer = torch.optim.Adam(rnn.parameters(), lr=LR)   # optimize all cnn parameters
loss_func = nn.MSELoss()

h_state = None      # for initial hidden state

# plt.figure(1, figsize=(12, 5))
# plt.ion()           # continuously plot

for step in range(350):
#     start, end = step * np.pi, (step+1)*np.pi   # time range
#     # use sin predicts cos
#     steps = np.linspace(start, end, TIME_STEP, dtype=np.float32, endpoint=False)  # float32 for converting torch FloatTensor
#     x_np = np.sin(steps)
#     y_np = np.cos(steps)

#     x = torch.from_numpy(x_np[np.newaxis, :, np.newaxis])    # shape (batch, time_step, input_size)
#     y = torch.from_numpy(y_np[np.newaxis, :, np.newaxis])
    input_torch = torch.from_numpy(input)
    output_torch = torch.from_numpy(output)
#     print(input1_torch.size())
    prediction = rnn(input_torch)   # rnn output
    # !! next step is important !!
#     h_state = h_state.data        # repack the hidden state, break the connection from last iteration
#     print(prediction.size())
#     print(output1_torch.size())
    loss = loss_func(prediction, output_torch)         # calculate loss
    print(loss)
    optimizer.zero_grad()                   # clear gradients for this training step
    loss.backward()                         # backpropagation, compute gradients
    optimizer.step()                        # apply gradients
       
    
    # plotting
#     plt.plot(steps, y_np.flatten(), 'r-')
#     plt.plot(steps, prediction.data.numpy().flatten(), 'b-')
    if step % 10 == 0:
        print(step)
        plt.plot(output.flatten(), 'r-')
        plt.plot(prediction.data.numpy().flatten(), 'b-')
        plt.draw(); plt.pause(0.05)
# Out:
# tensor(2.0235, grad_fn=<MseLossBackward>)
# 0
# tensor(2.4531, grad_fn=<MseLossBackward>)
# tensor(1.7880, grad_fn=<MseLossBackward>)
# tensor(1.7673, grad_fn=<MseLossBackward>)
# tensor(1.7931, grad_fn=<MseLossBackward>)
# tensor(1.7300, grad_fn=<MseLossBackward>)
# tensor(1.6423, grad_fn=<MseLossBackward>)
# tensor(1.5409, grad_fn=<MseLossBackward>)
# tensor(1.4393, grad_fn=<MseLossBackward>)
# tensor(1.3854, grad_fn=<MseLossBackward>)
# tensor(1.3339, grad_fn=<MseLossBackward>)
# 10
# tensor(1.2613, grad_fn=<MseLossBackward>)
# tensor(1.1934, grad_fn=<MseLossBackward>)
# tensor(1.1368, grad_fn=<MseLossBackward>)
# tensor(1.0756, grad_fn=<MseLossBackward>)
# tensor(1.0340, grad_fn=<MseLossBackward>)
# tensor(0.9891, grad_fn=<MseLossBackward>)
# tensor(0.9442, grad_fn=<MseLossBackward>)
# tensor(0.9099, grad_fn=<MseLossBackward>)
# tensor(0.8770, grad_fn=<MseLossBackward>)
# tensor(0.8384, grad_fn=<MseLossBackward>)
# 20
# tensor(0.8044, grad_fn=<MseLossBackward>)
# tensor(0.7812, grad_fn=<MseLossBackward>)
# tensor(0.7504, grad_fn=<MseLossBackward>)
# tensor(0.7212, grad_fn=<MseLossBackward>)
# tensor(0.7030, grad_fn=<MseLossBackward>)
# tensor(0.6764, grad_fn=<MseLossBackward>)
# tensor(0.6579, grad_fn=<MseLossBackward>)
# tensor(0.6405, grad_fn=<MseLossBackward>)
# tensor(0.6221, grad_fn=<MseLossBackward>)
# tensor(0.6105, grad_fn=<MseLossBackward>)
# 30
# tensor(0.5996, grad_fn=<MseLossBackward>)
# tensor(0.5866, grad_fn=<MseLossBackward>)
# tensor(0.5770, grad_fn=<MseLossBackward>)
# tensor(0.5659, grad_fn=<MseLossBackward>)
# tensor(0.5553, grad_fn=<MseLossBackward>)
# tensor(0.5441, grad_fn=<MseLossBackward>)
# tensor(0.5311, grad_fn=<MseLossBackward>)
# tensor(0.5203, grad_fn=<MseLossBackward>)
# tensor(0.5051, grad_fn=<MseLossBackward>)
# tensor(0.4966, grad_fn=<MseLossBackward>)
# 40
# tensor(0.4899, grad_fn=<MseLossBackward>)
# tensor(0.4808, grad_fn=<MseLossBackward>)
# tensor(0.4718, grad_fn=<MseLossBackward>)
# tensor(0.4650, grad_fn=<MseLossBackward>)
# tensor(0.4558, grad_fn=<MseLossBackward>)
# tensor(0.4496, grad_fn=<MseLossBackward>)
# tensor(0.4405, grad_fn=<MseLossBackward>)
# tensor(0.4334, grad_fn=<MseLossBackward>)
# tensor(0.4245, grad_fn=<MseLossBackward>)
# tensor(0.4162, grad_fn=<MseLossBackward>)
# 50
# tensor(0.4061, grad_fn=<MseLossBackward>)
# tensor(0.3965, grad_fn=<MseLossBackward>)
# tensor(0.3881, grad_fn=<MseLossBackward>)
# tensor(0.3797, grad_fn=<MseLossBackward>)
# tensor(0.3729, grad_fn=<MseLossBackward>)
# tensor(0.3665, grad_fn=<MseLossBackward>)
# tensor(0.3591, grad_fn=<MseLossBackward>)
# tensor(0.3512, grad_fn=<MseLossBackward>)
# tensor(0.3433, grad_fn=<MseLossBackward>)
# tensor(0.3360, grad_fn=<MseLossBackward>)
# 60
# tensor(0.3283, grad_fn=<MseLossBackward>)
# tensor(0.3208, grad_fn=<MseLossBackward>)
# tensor(0.3136, grad_fn=<MseLossBackward>)
# tensor(0.3065, grad_fn=<MseLossBackward>)
# tensor(0.2997, grad_fn=<MseLossBackward>)
# tensor(0.2948, grad_fn=<MseLossBackward>)
# tensor(0.2984, grad_fn=<MseLossBackward>)
# tensor(0.3017, grad_fn=<MseLossBackward>)
# tensor(0.2906, grad_fn=<MseLossBackward>)
# tensor(0.2755, grad_fn=<MseLossBackward>)
# 70
# tensor(0.2845, grad_fn=<MseLossBackward>)
# tensor(0.2725, grad_fn=<MseLossBackward>)
# tensor(0.2635, grad_fn=<MseLossBackward>)
# tensor(0.2688, grad_fn=<MseLossBackward>)
# tensor(0.2624, grad_fn=<MseLossBackward>)
# tensor(0.2505, grad_fn=<MseLossBackward>)
# tensor(0.2580, grad_fn=<MseLossBackward>)
# tensor(0.2509, grad_fn=<MseLossBackward>)
# tensor(0.2395, grad_fn=<MseLossBackward>)
# tensor(0.2428, grad_fn=<MseLossBackward>)
# 80
# tensor(0.2382, grad_fn=<MseLossBackward>)
# tensor(0.2322, grad_fn=<MseLossBackward>)
# tensor(0.2313, grad_fn=<MseLossBackward>)
# tensor(0.2303, grad_fn=<MseLossBackward>)
# tensor(0.2309, grad_fn=<MseLossBackward>)
# tensor(0.2246, grad_fn=<MseLossBackward>)
# tensor(0.2208, grad_fn=<MseLossBackward>)
# tensor(0.2227, grad_fn=<MseLossBackward>)
# tensor(0.2151, grad_fn=<MseLossBackward>)
# tensor(0.2176, grad_fn=<MseLossBackward>)
# 90
# tensor(0.2265, grad_fn=<MseLossBackward>)
# tensor(0.2188, grad_fn=<MseLossBackward>)
# tensor(0.2158, grad_fn=<MseLossBackward>)
# tensor(0.2140, grad_fn=<MseLossBackward>)
# tensor(0.2194, grad_fn=<MseLossBackward>)
# tensor(0.2028, grad_fn=<MseLossBackward>)
# tensor(0.2096, grad_fn=<MseLossBackward>)
# tensor(0.2070, grad_fn=<MseLossBackward>)
# tensor(0.1999, grad_fn=<MseLossBackward>)
# tensor(0.2021, grad_fn=<MseLossBackward>)
# 100
# tensor(0.1997, grad_fn=<MseLossBackward>)
# tensor(0.1977, grad_fn=<MseLossBackward>)
# tensor(0.1943, grad_fn=<MseLossBackward>)
# tensor(0.1960, grad_fn=<MseLossBackward>)
# tensor(0.1885, grad_fn=<MseLossBackward>)
# tensor(0.1898, grad_fn=<MseLossBackward>)
# tensor(0.1883, grad_fn=<MseLossBackward>)
# tensor(0.1875, grad_fn=<MseLossBackward>)
# tensor(0.1819, grad_fn=<MseLossBackward>)
# tensor(0.1827, grad_fn=<MseLossBackward>)
# 110
# tensor(0.1808, grad_fn=<MseLossBackward>)
# tensor(0.1800, grad_fn=<MseLossBackward>)
# tensor(0.1774, grad_fn=<MseLossBackward>)
# tensor(0.1745, grad_fn=<MseLossBackward>)
# tensor(0.1739, grad_fn=<MseLossBackward>)
# tensor(0.1718, grad_fn=<MseLossBackward>)
# tensor(0.1721, grad_fn=<MseLossBackward>)
# tensor(0.1708, grad_fn=<MseLossBackward>)
# tensor(0.1706, grad_fn=<MseLossBackward>)
# tensor(0.1730, grad_fn=<MseLossBackward>)
# 120
# tensor(0.1849, grad_fn=<MseLossBackward>)
# tensor(0.1950, grad_fn=<MseLossBackward>)
# tensor(0.2061, grad_fn=<MseLossBackward>)
# tensor(0.1812, grad_fn=<MseLossBackward>)
# tensor(0.1664, grad_fn=<MseLossBackward>)
# tensor(0.1867, grad_fn=<MseLossBackward>)
# tensor(0.1859, grad_fn=<MseLossBackward>)
# tensor(0.1647, grad_fn=<MseLossBackward>)
# tensor(0.1675, grad_fn=<MseLossBackward>)
# tensor(0.1771, grad_fn=<MseLossBackward>)
# 130
# tensor(0.1636, grad_fn=<MseLossBackward>)
# tensor(0.1591, grad_fn=<MseLossBackward>)
# tensor(0.1681, grad_fn=<MseLossBackward>)
# tensor(0.1597, grad_fn=<MseLossBackward>)
# tensor(0.1548, grad_fn=<MseLossBackward>)
# tensor(0.1606, grad_fn=<MseLossBackward>)
# tensor(0.1567, grad_fn=<MseLossBackward>)
# tensor(0.1512, grad_fn=<MseLossBackward>)
# tensor(0.1555, grad_fn=<MseLossBackward>)
# tensor(0.1533, grad_fn=<MseLossBackward>)
# 140
# tensor(0.1490, grad_fn=<MseLossBackward>)
# tensor(0.1492, grad_fn=<MseLossBackward>)
# tensor(0.1505, grad_fn=<MseLossBackward>)
# tensor(0.1468, grad_fn=<MseLossBackward>)
# tensor(0.1449, grad_fn=<MseLossBackward>)
# tensor(0.1453, grad_fn=<MseLossBackward>)
# tensor(0.1473, grad_fn=<MseLossBackward>)
# tensor(0.1454, grad_fn=<MseLossBackward>)
# tensor(0.1428, grad_fn=<MseLossBackward>)
# tensor(0.1408, grad_fn=<MseLossBackward>)
# 150
# tensor(0.1419, grad_fn=<MseLossBackward>)
# tensor(0.1416, grad_fn=<MseLossBackward>)
# tensor(0.1445, grad_fn=<MseLossBackward>)
# tensor(0.1435, grad_fn=<MseLossBackward>)
# tensor(0.1453, grad_fn=<MseLossBackward>)
# tensor(0.1440, grad_fn=<MseLossBackward>)
# tensor(0.1440, grad_fn=<MseLossBackward>)
# tensor(0.1394, grad_fn=<MseLossBackward>)
# tensor(0.1369, grad_fn=<MseLossBackward>)
# tensor(0.1341, grad_fn=<MseLossBackward>)
# 160
# tensor(0.1360, grad_fn=<MseLossBackward>)
# tensor(0.1363, grad_fn=<MseLossBackward>)
# tensor(0.1395, grad_fn=<MseLossBackward>)
# tensor(0.1405, grad_fn=<MseLossBackward>)
# tensor(0.1405, grad_fn=<MseLossBackward>)
# tensor(0.1403, grad_fn=<MseLossBackward>)
# tensor(0.1383, grad_fn=<MseLossBackward>)
# tensor(0.1344, grad_fn=<MseLossBackward>)
# tensor(0.1308, grad_fn=<MseLossBackward>)
# tensor(0.1299, grad_fn=<MseLossBackward>)
# 170
# tensor(0.1297, grad_fn=<MseLossBackward>)
# tensor(0.1310, grad_fn=<MseLossBackward>)
# tensor(0.1335, grad_fn=<MseLossBackward>)
# tensor(0.1345, grad_fn=<MseLossBackward>)
# tensor(0.1394, grad_fn=<MseLossBackward>)
# tensor(0.1427, grad_fn=<MseLossBackward>)
# tensor(0.1480, grad_fn=<MseLossBackward>)
# tensor(0.1435, grad_fn=<MseLossBackward>)
# tensor(0.1314, grad_fn=<MseLossBackward>)
# tensor(0.1256, grad_fn=<MseLossBackward>)
# 180
# tensor(0.1299, grad_fn=<MseLossBackward>)
# tensor(0.1350, grad_fn=<MseLossBackward>)
# tensor(0.1330, grad_fn=<MseLossBackward>)
# tensor(0.1251, grad_fn=<MseLossBackward>)
# tensor(0.1235, grad_fn=<MseLossBackward>)
# tensor(0.1266, grad_fn=<MseLossBackward>)
# tensor(0.1299, grad_fn=<MseLossBackward>)
# tensor(0.1274, grad_fn=<MseLossBackward>)
# tensor(0.1235, grad_fn=<MseLossBackward>)
# tensor(0.1202, grad_fn=<MseLossBackward>)
# 190
# tensor(0.1225, grad_fn=<MseLossBackward>)
# tensor(0.1242, grad_fn=<MseLossBackward>)
# tensor(0.1238, grad_fn=<MseLossBackward>)
# tensor(0.1228, grad_fn=<MseLossBackward>)
# tensor(0.1198, grad_fn=<MseLossBackward>)
# tensor(0.1177, grad_fn=<MseLossBackward>)
# tensor(0.1179, grad_fn=<MseLossBackward>)
# tensor(0.1184, grad_fn=<MseLossBackward>)
# tensor(0.1180, grad_fn=<MseLossBackward>)
# tensor(0.1208, grad_fn=<MseLossBackward>)
# 200
# tensor(0.1240, grad_fn=<MseLossBackward>)
# tensor(0.1270, grad_fn=<MseLossBackward>)
# tensor(0.1321, grad_fn=<MseLossBackward>)
# tensor(0.1363, grad_fn=<MseLossBackward>)
# tensor(0.1342, grad_fn=<MseLossBackward>)
# tensor(0.1251, grad_fn=<MseLossBackward>)
# tensor(0.1200, grad_fn=<MseLossBackward>)
# tensor(0.1165, grad_fn=<MseLossBackward>)
# tensor(0.1207, grad_fn=<MseLossBackward>)
# tensor(0.1239, grad_fn=<MseLossBackward>)
# 210
# tensor(0.1229, grad_fn=<MseLossBackward>)
# tensor(0.1182, grad_fn=<MseLossBackward>)
# tensor(0.1148, grad_fn=<MseLossBackward>)
# tensor(0.1155, grad_fn=<MseLossBackward>)
# tensor(0.1216, grad_fn=<MseLossBackward>)
# tensor(0.1225, grad_fn=<MseLossBackward>)
# tensor(0.1212, grad_fn=<MseLossBackward>)
# tensor(0.1140, grad_fn=<MseLossBackward>)
# tensor(0.1185, grad_fn=<MseLossBackward>)
# tensor(0.1127, grad_fn=<MseLossBackward>)
# 220
# tensor(0.1132, grad_fn=<MseLossBackward>)
# tensor(0.1122, grad_fn=<MseLossBackward>)
# tensor(0.1131, grad_fn=<MseLossBackward>)
# tensor(0.1147, grad_fn=<MseLossBackward>)
# tensor(0.1155, grad_fn=<MseLossBackward>)
# tensor(0.1116, grad_fn=<MseLossBackward>)
# tensor(0.1117, grad_fn=<MseLossBackward>)
# tensor(0.1101, grad_fn=<MseLossBackward>)
# tensor(0.1111, grad_fn=<MseLossBackward>)
# tensor(0.1108, grad_fn=<MseLossBackward>)
# 230
# tensor(0.1130, grad_fn=<MseLossBackward>)
# tensor(0.1146, grad_fn=<MseLossBackward>)
# tensor(0.1239, grad_fn=<MseLossBackward>)
# tensor(0.1363, grad_fn=<MseLossBackward>)
# tensor(0.1554, grad_fn=<MseLossBackward>)
# tensor(0.1536, grad_fn=<MseLossBackward>)
# tensor(0.1316, grad_fn=<MseLossBackward>)
# tensor(0.1092, grad_fn=<MseLossBackward>)
# tensor(0.1263, grad_fn=<MseLossBackward>)
# tensor(0.1399, grad_fn=<MseLossBackward>)
# 240
# tensor(0.1229, grad_fn=<MseLossBackward>)
# tensor(0.1092, grad_fn=<MseLossBackward>)
# tensor(0.1231, grad_fn=<MseLossBackward>)
# tensor(0.1243, grad_fn=<MseLossBackward>)
# tensor(0.1106, grad_fn=<MseLossBackward>)
# tensor(0.1115, grad_fn=<MseLossBackward>)
# tensor(0.1197, grad_fn=<MseLossBackward>)
# tensor(0.1110, grad_fn=<MseLossBackward>)
# tensor(0.1061, grad_fn=<MseLossBackward>)
# tensor(0.1134, grad_fn=<MseLossBackward>)
# 250
# tensor(0.1113, grad_fn=<MseLossBackward>)
# tensor(0.1044, grad_fn=<MseLossBackward>)
# tensor(0.1076, grad_fn=<MseLossBackward>)
# tensor(0.1102, grad_fn=<MseLossBackward>)
# tensor(0.1048, grad_fn=<MseLossBackward>)
# tensor(0.1031, grad_fn=<MseLossBackward>)
# tensor(0.1073, grad_fn=<MseLossBackward>)
# tensor(0.1053, grad_fn=<MseLossBackward>)
# tensor(0.1020, grad_fn=<MseLossBackward>)
# tensor(0.1030, grad_fn=<MseLossBackward>)
# 260
# tensor(0.1050, grad_fn=<MseLossBackward>)
# tensor(0.1035, grad_fn=<MseLossBackward>)
# tensor(0.1006, grad_fn=<MseLossBackward>)
# tensor(0.1009, grad_fn=<MseLossBackward>)
# tensor(0.1025, grad_fn=<MseLossBackward>)
# tensor(0.1021, grad_fn=<MseLossBackward>)
# tensor(0.1006, grad_fn=<MseLossBackward>)
# tensor(0.0992, grad_fn=<MseLossBackward>)
# tensor(0.0996, grad_fn=<MseLossBackward>)
# tensor(0.0998, grad_fn=<MseLossBackward>)
# 270
# tensor(0.1002, grad_fn=<MseLossBackward>)
# tensor(0.1000, grad_fn=<MseLossBackward>)
# tensor(0.1003, grad_fn=<MseLossBackward>)
# tensor(0.0980, grad_fn=<MseLossBackward>)
# tensor(0.0991, grad_fn=<MseLossBackward>)
# tensor(0.0985, grad_fn=<MseLossBackward>)
# tensor(0.0981, grad_fn=<MseLossBackward>)
# tensor(0.0975, grad_fn=<MseLossBackward>)
# tensor(0.0986, grad_fn=<MseLossBackward>)
# tensor(0.0969, grad_fn=<MseLossBackward>)
# 280
# tensor(0.0968, grad_fn=<MseLossBackward>)
# tensor(0.0962, grad_fn=<MseLossBackward>)
# tensor(0.0957, grad_fn=<MseLossBackward>)
# tensor(0.0958, grad_fn=<MseLossBackward>)
# tensor(0.0951, grad_fn=<MseLossBackward>)
# tensor(0.0954, grad_fn=<MseLossBackward>)
# tensor(0.0969, grad_fn=<MseLossBackward>)
# tensor(0.0970, grad_fn=<MseLossBackward>)
# tensor(0.0968, grad_fn=<MseLossBackward>)
# tensor(0.0975, grad_fn=<MseLossBackward>)
# 290
# tensor(0.1026, grad_fn=<MseLossBackward>)
# tensor(0.1167, grad_fn=<MseLossBackward>)
# tensor(0.1463, grad_fn=<MseLossBackward>)
# tensor(0.1958, grad_fn=<MseLossBackward>)
# tensor(0.2024, grad_fn=<MseLossBackward>)
# tensor(0.1429, grad_fn=<MseLossBackward>)
# tensor(0.1117, grad_fn=<MseLossBackward>)
# tensor(0.1488, grad_fn=<MseLossBackward>)
# tensor(0.1229, grad_fn=<MseLossBackward>)
# tensor(0.1092, grad_fn=<MseLossBackward>)
# 300
# tensor(0.1336, grad_fn=<MseLossBackward>)
# tensor(0.1212, grad_fn=<MseLossBackward>)
# tensor(0.1079, grad_fn=<MseLossBackward>)
# tensor(0.1271, grad_fn=<MseLossBackward>)
# tensor(0.1078, grad_fn=<MseLossBackward>)
# tensor(0.1101, grad_fn=<MseLossBackward>)
# tensor(0.1139, grad_fn=<MseLossBackward>)
# tensor(0.1022, grad_fn=<MseLossBackward>)
# tensor(0.1108, grad_fn=<MseLossBackward>)
# tensor(0.1020, grad_fn=<MseLossBackward>)
# 310
# tensor(0.1039, grad_fn=<MseLossBackward>)
# tensor(0.1044, grad_fn=<MseLossBackward>)
# tensor(0.1001, grad_fn=<MseLossBackward>)
# tensor(0.1012, grad_fn=<MseLossBackward>)
# tensor(0.1008, grad_fn=<MseLossBackward>)
# tensor(0.0973, grad_fn=<MseLossBackward>)
# tensor(0.0992, grad_fn=<MseLossBackward>)
# tensor(0.0977, grad_fn=<MseLossBackward>)
# tensor(0.0959, grad_fn=<MseLossBackward>)
# tensor(0.0973, grad_fn=<MseLossBackward>)
# 320
# tensor(0.0950, grad_fn=<MseLossBackward>)
# tensor(0.0949, grad_fn=<MseLossBackward>)
# tensor(0.0950, grad_fn=<MseLossBackward>)
# tensor(0.0930, grad_fn=<MseLossBackward>)
# tensor(0.0938, grad_fn=<MseLossBackward>)
# tensor(0.0944, grad_fn=<MseLossBackward>)
# tensor(0.0925, grad_fn=<MseLossBackward>)
# tensor(0.0926, grad_fn=<MseLossBackward>)
# tensor(0.0931, grad_fn=<MseLossBackward>)
# tensor(0.0913, grad_fn=<MseLossBackward>)
# 330
# tensor(0.0921, grad_fn=<MseLossBackward>)
# tensor(0.0910, grad_fn=<MseLossBackward>)
# tensor(0.0909, grad_fn=<MseLossBackward>)
# tensor(0.0903, grad_fn=<MseLossBackward>)
# tensor(0.0905, grad_fn=<MseLossBackward>)
# tensor(0.0897, grad_fn=<MseLossBackward>)
# tensor(0.0897, grad_fn=<MseLossBackward>)
# tensor(0.0891, grad_fn=<MseLossBackward>)
# tensor(0.0892, grad_fn=<MseLossBackward>)
# tensor(0.0887, grad_fn=<MseLossBackward>)
# 340
# tensor(0.0887, grad_fn=<MseLossBackward>)
# tensor(0.0881, grad_fn=<MseLossBackward>)
# tensor(0.0877, grad_fn=<MseLossBackward>)
# tensor(0.0876, grad_fn=<MseLossBackward>)
# tensor(0.0874, grad_fn=<MseLossBackward>)
# tensor(0.0873, grad_fn=<MseLossBackward>)
# tensor(0.0869, grad_fn=<MseLossBackward>)
# tensor(0.0870, grad_fn=<MseLossBackward>)
# tensor(0.0874, grad_fn=<MseLossBackward>)

# %%
test_input1 = np.delete(input1,0,2)
test_input1 = np.delete(test_input1,3,2)
input1_torch = torch.from_numpy(test_input1)
print(input1_torch.size())
output1_torch = torch.from_numpy(output1)
prediction_egg = rnn(input1_torch)/10
loss1 = loss_func(prediction_egg, output1_torch) 
print(loss1)
# Out:
# torch.Size([41, 500, 27])
# tensor(0.0010, grad_fn=<MseLossBackward>)

# %%
predict_egg = prediction_egg.data.numpy()
predict_egg = np.reshape(predict_egg,(-1,1))
print(np.shape(predict_egg))
# predict_input = np.reshape(test_input1,(-1,INPUT_SIZE))
# predict_input1 = predict_input[:,1:4]
# print(np.shape(predict_input1))
test_prediction = np.concatenate((predict_input[['//X', 'Y', 'Z']].to_numpy(), predict_egg), axis=1)
np.savetxt("test_prediction.csv", test_prediction, delimiter=",")
# Out:
# (20500, 1)
